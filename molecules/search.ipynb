# %% [markdown]
# # Search AiiDA Database Molecule optimizations

# %%
# %aiida
from apps.surfaces.widgets.search_completed_widget import SearchCompletedWidget

# %%
PREPROC_VERSION = 0.41
s=SearchCompletedWidget(
    version=PREPROC_VERSION,
    wlabel='MoleculeOptWorkChain',
    clabel='molecule_opt',
    fields_disable={}
)
display(s)
